# %% [markdown]
# # Homework
# Data documentation: https://tidyr.tidyverse.org/reference/who.html
#
# __Directions:__ Answer the three questions below. Create as many code/markdown blocks necessary to answer the questions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/who.csv')

# %%
df.head()
# Out:
#        country iso2 iso3  year  new_sp_m014  new_sp_m1524  new_sp_m2534  \
# 0  Afghanistan   AF  AFG  1980          NaN           NaN           NaN
# 1  Afghanistan   AF  AFG  1981          NaN           NaN           NaN
# 2  Afghanistan   AF  AFG  1982          NaN           NaN           NaN
# 3  Afghanistan   AF  AFG  1983          NaN           NaN           NaN
# 4  Afghanistan   AF  AFG  1984          NaN           NaN           NaN
#
#    new_sp_m3544  new_sp_m4554  new_sp_m5564  ...  newrel_m4554  newrel_m5564  \
# 0           NaN           NaN           NaN  ...           NaN           NaN
# 1           NaN           NaN           NaN  ...           NaN           NaN
# 2           NaN           NaN           NaN  ...           NaN           NaN
# 3           NaN           NaN           NaN  ...           NaN           NaN
# 4           NaN           NaN           NaN  ...           NaN           NaN
#
#    newrel_m65  newrel_f014  newrel_f1524  newrel_f2534  newrel_f3544  \
# 0         NaN          NaN           NaN           NaN           NaN
# 1         NaN          NaN           NaN           NaN           NaN
# 2         NaN          NaN           NaN           NaN           NaN
# 3         NaN          NaN           NaN           NaN           NaN
# 4         NaN          NaN           NaN           NaN           NaN
#
#    newrel_f4554  newrel_f5564  newrel_f65
# 0           NaN           NaN         NaN
# 1           NaN           NaN         NaN
# 2           NaN           NaN         NaN
# 3           NaN           NaN         NaN
# 4           NaN           NaN         NaN
#
# [5 rows x 60 columns]

# %%
df = df.drop(columns=['iso2', 'iso3'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7240 entries, 0 to 7239
# Data columns (total 58 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       7240 non-null   object
#  1   year          7240 non-null   int64
#  2   new_sp_m014   3173 non-null   float64
#  3   new_sp_m1524  3209 non-null   float64
#  4   new_sp_m2534  3206 non-null   float64
#  5   new_sp_m3544  3219 non-null   float64
#  6   new_sp_m4554  3223 non-null   float64
#  7   new_sp_m5564  3218 non-null   float64
#  8   new_sp_m65    3209 non-null   float64
#  9   new_sp_f014   3174 non-null   float64
#  10  new_sp_f1524  3194 non-null   float64
#  11  new_sp_f2534  3200 non-null   float64
#  12  new_sp_f3544  3199 non-null   float64
#  13  new_sp_f4554  3204 non-null   float64
#  14  new_sp_f5564  3195 non-null   float64
#  15  new_sp_f65    3197 non-null   float64
#  16  new_sn_m014   1045 non-null   float64
#  17  new_sn_m1524  1030 non-null   float64
#  18  new_sn_m2534  1022 non-null   float64
#  19  new_sn_m3544  1025 non-null   float64
#  20  new_sn_m4554  1027 non-null   float64
#  21  new_sn_m5564  1021 non-null   float64
#  22  new_sn_m65    1020 non-null   float64
#  23  new_sn_f014   1040 non-null   float64
#  24  new_sn_f1524  1022 non-null   float64
#  25  new_sn_f2534  1016 non-null   float64
#  26  new_sn_f3544  1020 non-null   float64
#  27  new_sn_f4554  1018 non-null   float64
#  28  new_sn_f5564  1017 non-null   float64
#  29  new_sn_f65    1019 non-null   float64
#  30  new_ep_m014   1038 non-null   float64
#  31  new_ep_m1524  1026 non-null   float64
#  32  new_ep_m2534  1020 non-null   float64
#  33  new_ep_m3544  1024 non-null   float64
#  34  new_ep_m4554  1020 non-null   float64
#  35  new_ep_m5564  1015 non-null   float64
#  36  new_ep_m65    1018 non-null   float64
#  37  new_ep_f014   1032 non-null   float64
#  38  new_ep_f1524  1021 non-null   float64
#  39  new_ep_f2534  1021 non-null   float64
#  40  new_ep_f3544  1021 non-null   float64
#  41  new_ep_f4554  1017 non-null   float64
#  42  new_ep_f5564  1017 non-null   float64
#  43  new_ep_f65    1014 non-null   float64
#  44  newrel_m014   190 non-null    float64
#  45  newrel_m1524  182 non-null    float64
#  46  newrel_m2534  183 non-null    float64
#  47  newrel_m3544  184 non-null    float64
#  48  newrel_m4554  184 non-null    float64
#  49  newrel_m5564  185 non-null    float64
#  50  newrel_m65    182 non-null    float64
#  51  newrel_f014   190 non-null    float64
#  52  newrel_f1524  184 non-null    float64
#  53  newrel_f2534  182 non-null    float64
#  54  newrel_f3544  183 non-null    float64
#  55  newrel_f4554  183 non-null    float64
#  56  newrel_f5564  183 non-null    float64
#  57  newrel_f65    185 non-null    float64
# dtypes: float64(56), int64(1), object(1)
# memory usage: 3.2+ MB

# %% [markdown]
# ## Question 1. We need to know what's included in this data.
# - How many countries are present?
# - What's the timespan of the data?
# - Does each country have a row for every year present?
# - Which countries are missing years?
# - How many rows have at least 1 non-null values across the columns 3-57?

# %%
# this is our dataframe
df
# Out:
#           country  year  new_sp_m014  new_sp_m1524  new_sp_m2534  \
# 0     Afghanistan  1980          NaN           NaN           NaN
# 1     Afghanistan  1981          NaN           NaN           NaN
# 2     Afghanistan  1982          NaN           NaN           NaN
# 3     Afghanistan  1983          NaN           NaN           NaN
# 4     Afghanistan  1984          NaN           NaN           NaN
# ...           ...   ...          ...           ...           ...
# 7235     Zimbabwe  2009        125.0         578.0           NaN
# 7236     Zimbabwe  2010        150.0         710.0        2208.0
# 7237     Zimbabwe  2011        152.0         784.0        2467.0
# 7238     Zimbabwe  2012        120.0         783.0        2421.0
# 7239     Zimbabwe  2013          NaN           NaN           NaN
#
#       new_sp_m3544  new_sp_m4554  new_sp_m5564  new_sp_m65  new_sp_f014  ...  \
# 0              NaN           NaN           NaN         NaN          NaN  ...
# 1              NaN           NaN           NaN         NaN          NaN  ...
# 2              NaN           NaN           NaN         NaN          NaN  ...
# 3              NaN           NaN           NaN         NaN          NaN  ...
# 4              NaN           NaN           NaN         NaN          NaN  ...
# ...            ...           ...           ...         ...          ...  ...
# 7235        3471.0         681.0         293.0       192.0        180.0  ...
# 7236        1682.0         761.0         350.0       252.0        173.0  ...
# 7237        2071.0         780.0         377.0       278.0        174.0  ...
# 7238        2086.0         796.0         360.0       271.0        173.0  ...
# 7239           NaN           NaN           NaN         NaN          NaN  ...
#
#       newrel_m4554  newrel_m5564  newrel_m65  newrel_f014  newrel_f1524  \
# 0              NaN           NaN         NaN          NaN           NaN
# 1              NaN           NaN         NaN          NaN           NaN
# 2              NaN           NaN         NaN          NaN           NaN
# 3              NaN           NaN         NaN          NaN           NaN
# 4              NaN           NaN         NaN          NaN           NaN
# ...            ...           ...         ...          ...           ...
# 7235           NaN           NaN         NaN          NaN           NaN
# 7236           NaN           NaN         NaN          NaN           NaN
# 7237           NaN           NaN         NaN          NaN           NaN
# 7238           NaN           NaN         NaN          NaN           NaN
# 7239        2349.0        1206.0      1208.0       1252.0        2069.0
#
#       newrel_f2534  newrel_f3544  newrel_f4554  newrel_f5564  newrel_f65
# 0              NaN           NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           NaN         NaN
# ...            ...           ...           ...           ...         ...
# 7235           NaN           NaN           NaN           NaN         NaN
# 7236           NaN           NaN           NaN           NaN         NaN
# 7237           NaN           NaN           NaN           NaN         NaN
# 7238           NaN           NaN           NaN           NaN         NaN
# 7239        4649.0        3526.0        1453.0         811.0       725.0
#
# [7240 rows x 58 columns]

# %%
# getting the count of unique countires so we can determine the number of countires present in the dataset
number_of_unique_countries = df["country"].unique().shape[0]
number_of_unique_countries
# Out:
# 219

# %%
print(f"There are a total of {number_of_unique_countries} unique countries available.")
# Out:
# There are a total of 219 unique countries available.

# %%
start_year = df["year"].min() # gives min year
end_year = df["year"].max() # gives max year
total_years = df["year"].unique().shape[0] # it gives the total nnumber of unique years

# finally printing the timespan along with the total number of years in the dataset
print(f"The timespan of the data is: {start_year} - {end_year}, for a total of {total_years}.")
# Out:
# The timespan of the data is: 1980 - 2013, for a total of 34.

# %%
'''
Groupping based on the country and the number of years we have.
we already have the total number of years. so, every county that has less number -
- of years than the total number of years will be considered for the missing years
'''
number_of_years_for_each_country = df.groupby("country")["year"].nunique()
number_of_years_for_each_country
# Out:
# country
# Afghanistan                  34
# Albania                      34
# Algeria                      34
# American Samoa               34
# Andorra                      34
#                              ..
# Wallis and Futuna Islands    34
# West Bank and Gaza Strip     34
# Yemen                        34
# Zambia                       34
# Zimbabwe                     34
# Name: year, Length: 219, dtype: int64

# %%
# using boolean masking to get the countires with missing years (less than the total number of years)
countries_with_missing_years = number_of_years_for_each_country[number_of_years_for_each_country != total_years]
countries_with_missing_years
# Out:
# country
# Bonaire, Saint Eustatius and Saba     4
# Curacao                               4
# Montenegro                            9
# Netherlands Antilles                 30
# Serbia                                9
# Serbia & Montenegro                  25
# Sint Maarten (Dutch part)             4
# South Sudan                           3
# Timor-Leste                          12
# Name: year, dtype: int64

# %% [markdown]
# <b> We can clearly see that not every country have data/row for all years. Lets also print the country names specifically

# %%
print("these are the countries with missing years: \n")

# iterating through the series and printing the names of countries with missing years
for idx, i in enumerate(dict(countries_with_missing_years).keys()):
    print("Country {idx}: {country}".format(idx=idx+1, country=i))
# Out:
# these are the countries with missing years:
#
# Country 1: Bonaire, Saint Eustatius and Saba
# Country 2: Curacao
# Country 3: Montenegro
# Country 4: Netherlands Antilles
# Country 5: Serbia
# Country 6: Serbia & Montenegro
# Country 7: Sint Maarten (Dutch part)
# Country 8: South Sudan
# Country 9: Timor-Leste

# %%
# this essentially slices the df to get only colummns from index position 3 to 57 inclusive
slicing_dataframe = df.iloc[:, 3:58]
slicing_dataframe
# Out:
#       new_sp_m1524  new_sp_m2534  new_sp_m3544  new_sp_m4554  new_sp_m5564  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2              NaN           NaN           NaN           NaN           NaN
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 7235         578.0           NaN        3471.0         681.0         293.0
# 7236         710.0        2208.0        1682.0         761.0         350.0
# 7237         784.0        2467.0        2071.0         780.0         377.0
# 7238         783.0        2421.0        2086.0         796.0         360.0
# 7239           NaN           NaN           NaN           NaN           NaN
#
#       new_sp_m65  new_sp_f014  new_sp_f1524  new_sp_f2534  new_sp_f3544  ...  \
# 0            NaN          NaN           NaN           NaN           NaN  ...
# 1            NaN          NaN           NaN           NaN           NaN  ...
# 2            NaN          NaN           NaN           NaN           NaN  ...
# 3            NaN          NaN           NaN           NaN           NaN  ...
# 4            NaN          NaN           NaN           NaN           NaN  ...
# ...          ...          ...           ...           ...           ...  ...
# 7235       192.0        180.0         873.0           NaN        3028.0  ...
# 7236       252.0        173.0         974.0        2185.0        1283.0  ...
# 7237       278.0        174.0        1084.0        2161.0        1386.0  ...
# 7238       271.0        173.0         939.0        2053.0        1286.0  ...
# 7239         NaN          NaN           NaN           NaN           NaN  ...
#
#       newrel_m4554  newrel_m5564  newrel_m65  newrel_f014  newrel_f1524  \
# 0              NaN           NaN         NaN          NaN           NaN
# 1              NaN           NaN         NaN          NaN           NaN
# 2              NaN           NaN         NaN          NaN           NaN
# 3              NaN           NaN         NaN          NaN           NaN
# 4              NaN           NaN         NaN          NaN           NaN
# ...            ...           ...         ...          ...           ...
# 7235           NaN           NaN         NaN          NaN           NaN
# 7236           NaN           NaN         NaN          NaN           NaN
# 7237           NaN           NaN         NaN          NaN           NaN
# 7238           NaN           NaN         NaN          NaN           NaN
# 7239        2349.0        1206.0      1208.0       1252.0        2069.0
#
#       newrel_f2534  newrel_f3544  newrel_f4554  newrel_f5564  newrel_f65
# 0              NaN           NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           NaN         NaN
# ...            ...           ...           ...           ...         ...
# 7235           NaN           NaN           NaN           NaN         NaN
# 7236           NaN           NaN           NaN           NaN         NaN
# 7237           NaN           NaN           NaN           NaN         NaN
# 7238           NaN           NaN           NaN           NaN         NaN
# 7239        4649.0        3526.0        1453.0         811.0       725.0
#
# [7240 rows x 55 columns]

# %%
# .notna() method will check if each value in each column is null or not; returns a bool
is_row_value_null = slicing_dataframe.notna()
is_row_value_null
# Out:
#       new_sp_m1524  new_sp_m2534  new_sp_m3544  new_sp_m4554  new_sp_m5564  \
# 0            False         False         False         False         False
# 1            False         False         False         False         False
# 2            False         False         False         False         False
# 3            False         False         False         False         False
# 4            False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 7235          True         False          True          True          True
# 7236          True          True          True          True          True
# 7237          True          True          True          True          True
# 7238          True          True          True          True          True
# 7239         False         False         False         False         False
#
#       new_sp_m65  new_sp_f014  new_sp_f1524  new_sp_f2534  new_sp_f3544  ...  \
# 0          False        False         False         False         False  ...
# 1          False        False         False         False         False  ...
# 2          False        False         False         False         False  ...
# 3          False        False         False         False         False  ...
# 4          False        False         False         False         False  ...
# ...          ...          ...           ...           ...           ...  ...
# 7235        True         True          True         False          True  ...
# 7236        True         True          True          True          True  ...
# 7237        True         True          True          True          True  ...
# 7238        True         True          True          True          True  ...
# 7239       False        False         False         False         False  ...
#
#       newrel_m4554  newrel_m5564  newrel_m65  newrel_f014  newrel_f1524  \
# 0            False         False       False        False         False
# 1            False         False       False        False         False
# 2            False         False       False        False         False
# 3            False         False       False        False         False
# 4            False         False       False        False         False
# ...            ...           ...         ...          ...           ...
# 7235         False         False       False        False         False
# 7236         False         False       False        False         False
# 7237         False         False       False        False         False
# 7238         False         False       False        False         False
# 7239          True          True        True         True          True
#
#       newrel_f2534  newrel_f3544  newrel_f4554  newrel_f5564  newrel_f65
# 0            False         False         False         False       False
# 1            False         False         False         False       False
# 2            False         False         False         False       False
# 3            False         False         False         False       False
# 4            False         False         False         False       False
# ...            ...           ...           ...           ...         ...
# 7235         False         False         False         False       False
# 7236         False         False         False         False       False
# 7237         False         False         False         False       False
# 7238         False         False         False         False       False
# 7239          True          True          True          True        True
#
# [7240 rows x 55 columns]

# %% [markdown]
# <b> Now that we have a bool value which represents the row/col position having null value or not, we can essentailly sum the corresponding row(True = 1 and False = 0). So that, if a row has at leaast one null value, the sum would be greater than 0.

# %%
# the any method will return true if any one of the rows (Axis=1) has a True value else False
#, and .sum() will get the total  count of rows with at least one value that is non-null
print("The number of rows with at least 1 not-null value is: ", is_row_value_null.any(axis=1).sum())
# Out:
# The number of rows with at least 1 not-null value is:  3484

# %% [markdown]
# ## Question 2: Wide data isn't usually helpful.
# Convert this to a long format with the following columns:
# 1. country
# 2. year
# 3. diagnosis method: mapping should be:
#
# ```
#   {'newsp':'Pulmonary Smear (+)'
#   ,'newsn':'Pulmonary Smear (-)'
#   ,'newep':'Extrapulmonary'
#   ,'newrel':'Relapse'}
#  ```
#
# 4. gender: male or female.
# 5. age: lower_age - higher_age, e.g., 0-14
# 6. number of cases
#
# __Note__: You can use `replace` (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html)

# %%
df.tail()
# Out:
#        country  year  new_sp_m014  new_sp_m1524  new_sp_m2534  new_sp_m3544  \
# 7235  Zimbabwe  2009        125.0         578.0           NaN        3471.0
# 7236  Zimbabwe  2010        150.0         710.0        2208.0        1682.0
# 7237  Zimbabwe  2011        152.0         784.0        2467.0        2071.0
# 7238  Zimbabwe  2012        120.0         783.0        2421.0        2086.0
# 7239  Zimbabwe  2013          NaN           NaN           NaN           NaN
#
#       new_sp_m4554  new_sp_m5564  new_sp_m65  new_sp_f014  ...  newrel_m4554  \
# 7235         681.0         293.0       192.0        180.0  ...           NaN
# 7236         761.0         350.0       252.0        173.0  ...           NaN
# 7237         780.0         377.0       278.0        174.0  ...           NaN
# 7238         796.0         360.0       271.0        173.0  ...           NaN
# 7239           NaN           NaN         NaN          NaN  ...        2349.0
#
#       newrel_m5564  newrel_m65  newrel_f014  newrel_f1524  newrel_f2534  \
# 7235           NaN         NaN          NaN           NaN           NaN
# 7236           NaN         NaN          NaN           NaN           NaN
# 7237           NaN         NaN          NaN           NaN           NaN
# 7238           NaN         NaN          NaN           NaN           NaN
# 7239        1206.0      1208.0       1252.0        2069.0        4649.0
#
#       newrel_f3544  newrel_f4554  newrel_f5564  newrel_f65
# 7235           NaN           NaN           NaN         NaN
# 7236           NaN           NaN           NaN         NaN
# 7237           NaN           NaN           NaN         NaN
# 7238           NaN           NaN           NaN         NaN
# 7239        3526.0        1453.0         811.0       725.0
#
# [5 rows x 58 columns]

# %%
# conver the pivot table back to long form from wide form
# the remaining group type columns will be melted with respect to country and year, and their values will be in the number_of_cases column
melted_df = df.melt(id_vars=['country', 'year'], var_name='group_type', value_name='number of cases')
melted_df
# Out:
#             country  year   group_type  number of cases
# 0       Afghanistan  1980  new_sp_m014              NaN
# 1       Afghanistan  1981  new_sp_m014              NaN
# 2       Afghanistan  1982  new_sp_m014              NaN
# 3       Afghanistan  1983  new_sp_m014              NaN
# 4       Afghanistan  1984  new_sp_m014              NaN
# ...             ...   ...          ...              ...
# 405435     Zimbabwe  2009   newrel_f65              NaN
# 405436     Zimbabwe  2010   newrel_f65              NaN
# 405437     Zimbabwe  2011   newrel_f65              NaN
# 405438     Zimbabwe  2012   newrel_f65              NaN
# 405439     Zimbabwe  2013   newrel_f65            725.0
#
# [405440 rows x 4 columns]

# %%
# we don't need null values now
melted_df = melted_df.dropna()
melted_df = melted_df.reset_index(drop=True)

# %%
melted_df.group_type.values[0]
# Out:
# 'new_sp_m014'

# %% [markdown]
# <b> if we look here.
#     new_sp -> newsp (meaning pulmonary smear (+))
#     similarly, m means male
#     014 means age_group 0-14
# </b>
#
# I will use regular expressions to extract those values

# %%
import re

# this is our pattern

'''
here () means one group. since we are extracting diagnosis method, gender and age groups, we have 3 groups. lets look at them
    1. (new_?[a-z]+) -> starts with new, followed by _ (? means there can be _ or not. its optional). followed 
                - by [a-z]+ meaning a-z smaller cap characters at least once. this gives us our diagnosis.
                - followed by a compulsory _
    2. ([mf]) -> another group where one only one character m or f is selected. m being male and f being female.
    3. (\d+) -> final group where there can be more than 1 numeric values. same as [0-9]+ for the age group

'''
pattern = r"(new_?[a-z]+)_([mf])(\d+)"

match = re.search(pattern, 'new_sp_m014')

if match:   
    print("diagnosis method: ",  match.group(1) )
    print("gender: ", match.group(2) )
    print("age grroup:", match.group(3))
# Out:
# diagnosis method:  new_sp
# gender:  m
# age grroup: 014

# %% [markdown]
# We can do this in pandas using .str.extract() method directly

# %%
# accessing the new features
melted_df[["diagnosis method", "gender", "age"]] = melted_df["group_type"].str.extract(r"(new_?[a-z]+)_([mf])(\d+)")

# %%
melted_df.head()
# Out:
#        country  year   group_type  number of cases diagnosis method gender  \
# 0  Afghanistan  1997  new_sp_m014              0.0           new_sp      m
# 1  Afghanistan  1998  new_sp_m014             30.0           new_sp      m
# 2  Afghanistan  1999  new_sp_m014              8.0           new_sp      m
# 3  Afghanistan  2000  new_sp_m014             52.0           new_sp      m
# 4  Afghanistan  2001  new_sp_m014            129.0           new_sp      m
#
#    age
# 0  014
# 1  014
# 2  014
# 3  014
# 4  014

# %%
melted_df["diagnosis method"].unique()
# Out:
# array(['new_sp', 'new_sn', 'new_ep', 'newrel'], dtype=object)

# %%
# lets map the diagnosis method to original values
diagnosis_map = {
    'new_sp': 'Pulmonary Smear (+)',
    'new_sn': 'Pulmonary Smear (-)',
    'new_ep': 'Extrapulmonary',
    'newrel': 'Relapse'
}

# gender mapping
gender_map = {
    "m": "Male",
    "f": "Female"
}

melted_df["diagnosis method"] = melted_df["diagnosis method"].map(diagnosis_map)
melted_df["gender"] = melted_df["gender"].map(gender_map)

# %%
# lets convert ages to age brackets using slicing
melted_df["age"] = melted_df["age"].apply(lambda x : x[0:-2]+ "-" + x[-2:] if x != '65' else "65+")

# %%
# rearranging columns
melted_df = melted_df[["country", "year", "diagnosis method", "gender", "age", "number of cases"]]

# %%
melted_df
# Out:
#                          country  year     diagnosis method  gender   age  \
# 0                    Afghanistan  1997  Pulmonary Smear (+)    Male  0-14
# 1                    Afghanistan  1998  Pulmonary Smear (+)    Male  0-14
# 2                    Afghanistan  1999  Pulmonary Smear (+)    Male  0-14
# 3                    Afghanistan  2000  Pulmonary Smear (+)    Male  0-14
# 4                    Afghanistan  2001  Pulmonary Smear (+)    Male  0-14
# ...                          ...   ...                  ...     ...   ...
# 76041                   Viet Nam  2013              Relapse  Female   65+
# 76042  Wallis and Futuna Islands  2013              Relapse  Female   65+
# 76043                      Yemen  2013              Relapse  Female   65+
# 76044                     Zambia  2013              Relapse  Female   65+
# 76045                   Zimbabwe  2013              Relapse  Female   65+
#
#        number of cases
# 0                  0.0
# 1                 30.0
# 2                  8.0
# 3                 52.0
# 4                129.0
# ...                ...
# 76041           3110.0
# 76042              2.0
# 76043            360.0
# 76044            669.0
# 76045            725.0
#
# [76046 rows x 6 columns]

# %% [markdown]
# ## Question 3: Create a graph that shows when countries started to report TB cases.

# %%
melted_df
# Out:
#                          country  year     diagnosis method  gender   age  \
# 0                    Afghanistan  1997  Pulmonary Smear (+)    Male  0-14
# 1                    Afghanistan  1998  Pulmonary Smear (+)    Male  0-14
# 2                    Afghanistan  1999  Pulmonary Smear (+)    Male  0-14
# 3                    Afghanistan  2000  Pulmonary Smear (+)    Male  0-14
# 4                    Afghanistan  2001  Pulmonary Smear (+)    Male  0-14
# ...                          ...   ...                  ...     ...   ...
# 76041                   Viet Nam  2013              Relapse  Female   65+
# 76042  Wallis and Futuna Islands  2013              Relapse  Female   65+
# 76043                      Yemen  2013              Relapse  Female   65+
# 76044                     Zambia  2013              Relapse  Female   65+
# 76045                   Zimbabwe  2013              Relapse  Female   65+
#
#        number of cases
# 0                  0.0
# 1                 30.0
# 2                  8.0
# 3                 52.0
# 4                129.0
# ...                ...
# 76041           3110.0
# 76042              2.0
# 76043            360.0
# 76044            669.0
# 76045            725.0
#
# [76046 rows x 6 columns]

# %%
# lets check when each country started reporting TB
countries_and_their_first_reporting_year = melted_df[melted_df["number of cases"] > 0].groupby("country")["year"].min().reset_index().sort_values("year", ascending=True)
countries_and_their_first_reporting_year
# Out:
#                               country  year
# 36                             Canada  1980
# 47                       Cook Islands  1980
# 124                          Mongolia  1994
# 68                               Fiji  1994
# 104  Lao People's Democratic Republic  1995
# ..                                ...   ...
# 78                          Greenland  2009
# 52                            Curacao  2010
# 173         Sint Maarten (Dutch part)  2010
# 179                       South Sudan  2011
# 10                              Aruba  2011
#
# [217 rows x 2 columns]

# %% [markdown]
# It looks like Canada was among the nations with earliest reporting on TB.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(countries_and_their_first_reporting_year['year'], bins=20, kde=True, discrete=True)

plt.xlabel("Year")
plt.ylabel("Number of Countries")
plt.title("Number of Countries Reporting TB Cases for the First Time")
plt.grid(True)
plt.show()

# %% [markdown]
# if we look at above histogram, it shows that the earliest reporting was in 1980s with very few reports. However, in the mid 1990s, there is a huge surge of TB reports.
